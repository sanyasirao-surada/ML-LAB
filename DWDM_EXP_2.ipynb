# %% [markdown]
# <a href="https://colab.research.google.com/github/sanyasirao-surada/ML-LAB/blob/main/DWDM_EXP_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Experiment 2: Understanding Data
# Author: Student Name
# Date: DD/MM/YYYY

import pandas as pd
import numpy as np

print("EXPERIMENT 2 : UNDERSTANDING DATA")

# ============================
# Step 1: Upload CSV in Colab
# ============================
from google.colab import files
uploaded = files.upload()

file_name = list(uploaded.keys())[0]

# ============================
# Step 2: Load Dataset
# ============================
df = pd.read_csv(file_name)
print("\nDataset Loaded Successfully!")

# ============================
# Step 3: Basic Information
# ============================
print("\nShape of Dataset:", df.shape)
print("\nColumn Names:\n", df.columns)
print("\nData Types:\n", df.dtypes)

# ============================
# Step 4: Sample Records
# ============================
print("\nFirst 5 Records:\n", df.head())
print("\nLast 5 Records:\n", df.tail())

# ============================
# Step 5: Statistical Summary
# ============================
print("\nStatistical Summary:\n", df.describe())

# ============================
# Step 6: Missing Values
# ============================
print("\nMissing Values in Each Column:\n", df.isnull().sum())

print("\nExperiment 2 Completed Successfully")
# Out:
# EXPERIMENT 2 : UNDERSTANDING DATA
#      <input type="file" id="files-48917506-5775-45b2-aad3-38ec9e21e330" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-48917506-5775-45b2-aad3-38ec9e21e330">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...
