# %% [markdown]
# <a href="https://colab.research.google.com/github/sanyasirao-surada/ML-LAB/blob/main/DWDM_EXP_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Experiment 3
# Correlation Matrix Analysis

# Import required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset from CSV
df = pd.read_csv("/content/student_performance_correlation.csv")

# Display first rows
print("Dataset Preview")
print(df.head())

# Display statistical summary
print("\nStatistical Summary")
print(df.describe())

# Calculate correlation matrix
correlation_matrix = df.corr()

print("\nCorrelation Matrix")
print(correlation_matrix)

# Plot correlation heatmap
plt.figure(figsize=(10,8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix Heatmap")
plt.show()
# Out:
# Dataset Preview
#    StudentID  Study_Hours  Attendance_Percent  Previous_CGPA  \
# 0          1            7                  63           8.33
# 1          2            4                  61           8.07
# 2          3            8                  65           6.96
# 3          4            5                  63           7.96
# 4          5            7                  88           7.34
#
#    Assignment_Score  Lab_Score  Midterm_Score  Project_Score  Final_Score
# 0                91         94             82             90           68
# 1                91         93             53             94           55
# 2                83         72             82             92           65
# 3                71         94             63             80           55
# 4                98         55             70             91           68
#
# Statistical Summary
#        StudentID  Study_Hours  Attendance_Percent  Previous_CGPA  \
# ...
